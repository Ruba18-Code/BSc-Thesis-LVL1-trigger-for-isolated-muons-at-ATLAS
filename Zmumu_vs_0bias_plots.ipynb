# %%
import uproot
import numpy as np #math and science package
import scipy as sp #math and science package
import awkward as ak #root files are usuallt awkward arrays 
import matplotlib.pyplot as plt #plot stuff

from my_functions import invariant_mass_all_muons
from my_functions import histogram2 
from my_functions import invariant_mass
from my_functions import quality_locator
from my_functions import quality_selector
from my_functions import high_quality_histogram2
from my_functions import histogram2errors

# %%
file= uproot.open("/home/ruben/Escritorio/BachelorThesisRuben/Data/Muon_trees.root") #opening the Root file with Uproot 

file.keys() #Here we can see the keys of the file (index)
# Out:
# ['MuonTree_Zmumu;1', 'MuonTree_ZeroBias;1']

# %%
MuonTree_Zmumu=file["MuonTree_Zmumu;1"] 
MuonTree_Back=file["MuonTree_ZeroBias;1"]

MuonTree_Zmumu.show() #Let's see which plots can we do. We're going to focus on the offline muons (the ones with name muon_something).
                      #We're going to plot the Zmumu data together with the 0 bias (background) in order to compare them.
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# muon_pt              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# muon_eta             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# muon_phi             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# muon_e               | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# muon_type            | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# muon_charge          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# muon_author          | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# muon_quality         | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# muon_passedIDCuts    | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# jTower_et            | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ...

# %%
data1=MuonTree_Zmumu["muon_eta"].array()
data2=MuonTree_Back["muon_eta"].array()

nbins=50
x_range=[-3,3]
x_label=r"Muon transverse momentum $p_T$ (MeV)"
y_label="Counts"
title_label=r"Muon counts vs $p_T$ ATLAS Detector"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Background data'

histogram2(data1,data2,nbins,x_range,x_label,y_label,title_label,label1,label2)

# %%
data1=MuonTree_Zmumu["muon_eta"].array()
data2=MuonTree_Back["muon_eta"].array()

nbins=80
x_range=None
x_label=r"Muon eta ($\eta$)"
y_label="Counts"
title_label=r"Muon counts vs $\eta$ ATLAS Detector"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Background data'

histogram2(data1,data2,nbins,x_range,x_label,y_label,title_label,label1,label2)

# %%
data1=MuonTree_Zmumu["muon_phi"].array()
data2=MuonTree_Back["muon_phi"].array()

nbins=80
x_range=None
x_label=r"Muon phi ($\phi$)"
y_label="Counts"
title_label=r"Muon counts vs $\phi$ ATLAS Detector"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Background data'

histogram2(data1,data2,nbins,x_range,x_label,y_label,title_label,label1,label2)

# %%
data1=MuonTree_Zmumu["muon_e"].array()
data2=MuonTree_Back["muon_e"].array()

nbins=80
x_range=[0,2*10**5]
x_label=r"Muon energy (MeV)"
y_label="Counts"
title_label=r"Muon counts vs energy ATLAS Detector"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Background data'

histogram2(data1,data2,nbins,x_range,x_label,y_label,title_label,label1,label2)

# %%
data1=MuonTree_Zmumu["muon_type"].array()
data2=MuonTree_Back["muon_type"].array()

nbins=50
x_range=None
x_label=r"Muon type"
y_label="Counts"
title_label=r"Muon counts vs type ATLAS Detector"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Background data'

histogram2(data1,data2,nbins,x_range,x_label,y_label,title_label,label1,label2)

# %%
data1=MuonTree_Zmumu["muon_charge"].array()
data2=MuonTree_Back["muon_charge"].array()

nbins=50
x_range=None
x_label=r"Muon charge (e-)"
y_label="Counts"
title_label=r"Muon counts vs charge ATLAS Detector"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Background data'

histogram2(data1,data2,nbins,x_range,x_label,y_label,title_label,label1,label2)

# %%
data1=MuonTree_Zmumu["muon_author"].array()
data2=MuonTree_Back["muon_author"].array()

nbins=50
x_range=None
x_label=r"Muon author"
y_label="Counts"
title_label=r"Muon counts vs author ATLAS Detector"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Background data'

histogram2(data1,data2,nbins,x_range,x_label,y_label,title_label,label1,label2)

# %%
data1=MuonTree_Zmumu["muon_quality"].array()
data2=MuonTree_Back["muon_quality"].array()

nbins=50
x_range=None
x_label=r"Muon quality"
y_label="Counts"
title_label=r"Muon counts vs quality ATLAS Detector"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Background data'

histogram2(data1,data2,nbins,x_range,x_label,y_label,title_label,label1,label2)

# %%
data1=MuonTree_Zmumu["muon_quality"].array()
data2=MuonTree_Back["muon_quality"].array()

nbins=50
x_range=None
x_label=r"Muon quality"
y_label="Counts"
title_label=r"Muon counts vs quality ATLAS Detector"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Background data'

histogram2(data1,data2,nbins,x_range,x_label,y_label,title_label,label1,label2)

# %% [markdown]
# ## QUALITY 0 PLOTS

# %%
data1=MuonTree_Zmumu["muon_quality"]
value=0

# %%
data1=MuonTree_Zmumu["muon_pt"].array()
data1_quality=MuonTree_Zmumu["muon_quality"].array()

data2=MuonTree_Back["muon_pt"].array()
data2_quality=MuonTree_Back["muon_quality"].array()

nbins=40
x_range=[0,65000]
x_label=r"Muon transverse momentum $p_T$ (MeV)"
y_label="Counts"
title_label=r"Muon counts vs $p_T$ ATLAS Detector (Quality=0)"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Zero Bias data'

high_quality_histogram2(data1,data1_quality,data2,data2_quality,nbins,x_range,x_label,y_label,title_label,label1,label2)
# Out:
# Only 21.265 % of the data has been selected
# Only 43.8645 % of the data has been selected

# %%
data1=MuonTree_Zmumu["muon_eta"].array()
data1_quality=MuonTree_Zmumu["muon_quality"].array()

data2=MuonTree_Back["muon_eta"].array()
data2_quality=MuonTree_Back["muon_quality"].array()

nbins=40
x_range=None
x_label=r"Pseudorapidity ($\eta$)"
y_label="Counts"
title_label=r"Muon counts vs $\eta$ ATLAS Detector (Quality=0)"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Zero Bias data'

high_quality_histogram2(data1,data1_quality,data2,data2_quality,nbins,x_range,x_label,y_label,title_label,label1,label2)
# Out:
# Only 21.265 % of the data has been selected
# Only 43.8645 % of the data has been selected

# %%
data1=MuonTree_Zmumu["muon_phi"].array()
data1_quality=MuonTree_Zmumu["muon_quality"].array()

data2=MuonTree_Back["muon_phi"].array()
data2_quality=MuonTree_Back["muon_quality"].array()

nbins=40
x_range=None
x_label=r"Angle ($\phi$)"
y_label="Counts"
title_label=r"Muon counts vs $\phi$ ATLAS Detector (Quality=0)"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Zero Bias data'

high_quality_histogram2(data1,data1_quality,data2,data2_quality,nbins,x_range,x_label,y_label,title_label,label1,label2)
# Out:
# Only 21.265 % of the data has been selected
# Only 43.8645 % of the data has been selected

# %%
data1=MuonTree_Zmumu["muon_e"].array()
data1_quality=MuonTree_Zmumu["muon_quality"].array()

data2=MuonTree_Back["muon_e"].array()
data2_quality=MuonTree_Back["muon_quality"].array()

nbins=40
x_range=[0,2*10**5]
x_label=r"Muon Energy (MeV)"
y_label="Counts"
title_label=r"Muon counts vs E ATLAS Detector (Quality=0)"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Zero Bias data'

high_quality_histogram2(data1,data1_quality,data2,data2_quality,nbins,x_range,x_label,y_label,title_label,label1,label2)
# Out:
# Only 21.265 % of the data has been selected
# Only 43.8645 % of the data has been selected

# %%
data1=MuonTree_Zmumu["muon_type"].array()
data1_quality=MuonTree_Zmumu["muon_quality"].array()

data2=MuonTree_Back["muon_type"].array()
data2_quality=MuonTree_Back["muon_quality"].array()

nbins=40
x_range=None
x_label=r"Muon type"
y_label="Counts"
title_label=r"Muon counts vs type ATLAS Detector (Quality=0)"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Zero Bias data'

high_quality_histogram2(data1,data1_quality,data2,data2_quality,nbins,x_range,x_label,y_label,title_label,label1,label2)
# Out:
# Only 21.265 % of the data has been selected
# Only 43.8645 % of the data has been selected

# %%
data1=MuonTree_Zmumu["muon_charge"].array()
data1_quality=MuonTree_Zmumu["muon_quality"].array()

data2=MuonTree_Back["muon_charge"].array()
data2_quality=MuonTree_Back["muon_quality"].array()

nbins=40
x_range=None
x_label=r"Charge (e-)"
y_label="Counts"
title_label=r"Muon counts vs charge ATLAS Detector (Quality=0)"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Zero Bias data'

high_quality_histogram2(data1,data1_quality,data2,data2_quality,nbins,x_range,x_label,y_label,title_label,label1,label2)
# Out:
# Only 21.265 % of the data has been selected
# Only 43.8645 % of the data has been selected

# %%
data1=MuonTree_Zmumu["muon_author"].array()
data1_quality=MuonTree_Zmumu["muon_quality"].array()

data2=MuonTree_Back["muon_author"].array()
data2_quality=MuonTree_Back["muon_quality"].array()

nbins=40
x_range=None
x_label=r"Author"
y_label="Counts"
title_label=r"Muon counts vs author ATLAS Detector (Quality=0)"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Zero Bias data'

high_quality_histogram2(data1,data1_quality,data2,data2_quality,nbins,x_range,x_label,y_label,title_label,label1,label2)
# Out:
# Only 21.265 % of the data has been selected
# Only 43.8645 % of the data has been selected

# %%
data1=MuonTree_Zmumu["muon_quality"].array()
data1_quality=MuonTree_Zmumu["muon_quality"].array()

data2=MuonTree_Back["muon_quality"].array()
data2_quality=MuonTree_Back["muon_quality"].array()

nbins=40
x_range=None
x_label=r"Quality"
y_label="Counts"
title_label=r"Muon counts vs quality Detector (Quality=0)"
label1=r'Z $\longrightarrow \mu \mu$ data'
label2='Zero Bias data'

high_quality_histogram2(data1,data1_quality,data2,data2_quality,nbins,x_range,x_label,y_label,title_label,label1,label2)
# Out:
# Only 21.265 % of the data has been selected
# Only 43.8645 % of the data has been selected
