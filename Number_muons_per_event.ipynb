# %%
import uproot
import numpy as np #math and science package
import scipy as sp #math and science package
import awkward as ak #root files are usuallt awkward arrays 
import matplotlib.pyplot as plt #plot stuff

from my_functions import invariant_mass_all_muons
from my_functions import histogram2 
from my_functions import invariant_mass
from my_functions import plot_number_mu_per_event 
from my_functions import plot_number_mu_per_event2

# %%
file= uproot.open("/home/ruben/Escritorio/BachelorThesisRuben/Data/Muon_trees.root") #opening the Root file with Uproot 

MuonTree_Zmumu=file["MuonTree_Zmumu;1"] 
MuonTree_Back=file["MuonTree_ZeroBias;1"]

# %%
data=MuonTree_Zmumu["muon_phi"].array()
plot_number_mu_per_event(data)

# %%
data1=MuonTree_Zmumu["muon_eta"].array()
data2=MuonTree_Back["muon_eta"].array()
label1=r"Z $\longrightarrow \mu \mu$"
label2="Background"
nbins=8
x_label="Number of Muons recorded"
y_label="Counts"
title_label="Number of recorded muons per event"
x_range=None

plot_number_mu_per_event2(data1,data2,label1,label2)
